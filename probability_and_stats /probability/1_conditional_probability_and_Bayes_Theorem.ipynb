# %% [markdown]
# <a href="https://colab.research.google.com/github/vyavasthita/dsml_learning/blob/master/probability_and_stats%20/probability/1_conditional_probability_and_Bayes_Theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7 -O Sachin_ODI.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# read data from github: https://github.com/SachinScaler/ProbabilityAndStats_Nov2025
df_sachin = pd.read_csv('https://raw.githubusercontent.com/SachinScaler/ProbabilityAndStats_Nov2025/refs/heads/main/Sachin_ODI.csv')
df_sachin.head()

# %%
df_sachin[["century","Won"]].value_counts()

# %% [markdown]
# #### Q1. A match is randomly chosen, what is the probability that India have won that match?

# %%
df_sachin["Won"].value_counts()

# %%
184 / (184 + 176)

# %% [markdown]
# #### Q2. A match is chosen at a random, what is the probability that Sachin has scored a Century in that match?

# %%
df_sachin["century"].value_counts()

# %%
46 / (314 + 46)

# %% [markdown]
# #### Q3: find out how many matches India have won when Sachin has scored a century and
# #### How many matches India have won when sachin didn't score a century.

# %%
df_sachin[["century","Won"]].value_counts()

# %%
 # A: find out how many matches India have won when Sachin has scored a century
 # ans: 30

# B: find out how many matches India have won when sachin didn't score a century
 # ans: 154

# %% [markdown]
# #### Q4. A match is chosen at a random. What is the probability that Sachin has scored a century in that match and India have won that match?
#
# HINT: P(W and C)

# %%
len(df_sachin)

# %%
30 / 360

# %%
df_sachin[["century","Won"]].value_counts()

# %%
pd.crosstab(index = df_sachin["century"],
            columns= df_sachin["Won"],
            margins = True)

# %%
# count(Century intersection win) = 30
# p(Century intersection win) = 30 / 360
